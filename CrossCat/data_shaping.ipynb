# %%
import pandas as pd

# %%
train = pd.read_excel("train_test_data/DSM_Train1.xlsx")

# %%
test = pd.read_excel("train_test_data/DSM_Test1.xlsx")

# %%
train.shape
# Out:
# (177, 1034)

# %%
test.shape
# Out:
# (44, 1034)

# %%
unsplit = pd.concat([train, test])

# %%
unsplit.shape
# Out:
# (221, 1034)

# %%
drops = ["APQ_SR_CP",
        "APQ_SR_ID",
        "APQ_SR_INV_D",
        "APQ_SR_INV_M",
        "APQ_SR_OPD",
        "APQ_SR_PM",
        "APQ_SR_PP",
        "ASR_AB",
        "ASR_AB_T",
        "ASR_AD",
        "ASR_AD_T",
        "ASR_AP",
        "ASR_AP_T",
        "ASR_C",
        "ASR_Ext",
        "ASR_Ext_T",
        "ASR_Int",
        "ASR_Int_T",
        "ASR_Intrusive",
        "ASR_Intrusive_T",
        "ASR_OP",
        "ASR_RBB",
        "ASR_RBB_T",
        "ASR_SC",
        "ASR_SC_T",
        "ASR_TP",
        "ASR_TP_T",
        "ASR_WD",
        "ASR_WD_T",
        "C3SR_AG",
        "C3SR_AG_T",
        "C3SR_FR",
        "C3SR_FR_T",
        "C3SR_HY",
        "C3SR_HY_T",
        "C3SR_IN",
        "C3SR_IN_T",
        "C3SR_LP",
        "C3SR_LP_T",
        "C3SR_NI",
        "C3SR_PI",
        "CAARS_ADHD_Raw",
        "CAARS_ADHD_T",
        "CAARS_HR_Raw",
        "CAARS_HR_T",
        "CAARS_IE_Raw",
        "CAARS_IE_T",
        "CAARS_IM_Raw",
        "CAARS_IM_T",
        "CAARS_SC_Raw",
        "CAARS_SC_T",
        "CBCL_AB",
        "CBCL_AB_T",
        "CBCL_AD",
        "CBCL_AD_T",
        "CBCL_AP",
        "CBCL_AP_T",
        "CBCL_C",
        "CBCL_Ext",
        "CBCL_Ext_T",
        "CBCL_Int",
        "CBCL_Int_T",
        "CBCL_OP",
        "CBCL_Pre_AB",
        "CBCL_Pre_AB_T",
        "CBCL_Pre_AD",
        "CBCL_Pre_AD_T",
        "CBCL_Pre_AP",
        "CBCL_Pre_AP_T",
        "CBCL_Pre_DSM_ADHP",
        "CBCL_Pre_DSM_ADHP_T",
        "CBCL_Pre_DSM_AnxP",
        "CBCL_Pre_DSM_AnxP_T",
        "CBCL_Pre_DSM_AP",
        "CBCL_Pre_DSM_AP_T",
        "CBCL_Pre_DSM_ODP",
        "CBCL_Pre_DSM_ODP_T",
        "CBCL_Pre_DSM_PDP",
        "CBCL_Pre_DSM_PDP_T",
        "CBCL_Pre_Ext",
        "CBCL_Pre_Ext_T",
        "CBCL_Pre_Int",
        "CBCL_Pre_Int_T",
        "CBCL_Pre_OP",
        "CBCL_Pre_SC",
        "CBCL_Pre_SC_T",
        "CBCL_Pre_SP",
        "CBCL_Pre_SP_T",
        "CBCL_Pre_WD",
        "CBCL_Pre_WD_T",
        "CBCL_RBB",
        "CBCL_RBB_T",
        "CBCL_SC",
        "CBCL_SC_T",
        "CBCL_SP",
        "CBCL_SP_T",
        "CBCL_TP",
        "CBCL_TP_T",
        "CBCL_WD",
        "CBCL_WD_T",
        "CCSC_AA",
        "CCSC_AC",
        "CCSC_CDM",
        "CCSC_CON",
        "CCSC_DPS",
        "CCSC_OPT",
        "CCSC_PCR",
        "CCSC_PFC",
        "CCSC_POS",
        "CCSC_REL",
        "CCSC_REP",
        "CCSC_SS",
        "CCSC_SU",
        "CCSC_SUPEER",
        "CCSC_SUPMF",
        "CCSC_SUPOA",
        "CCSC_SUPSIB",
        "CCSC_WT",
        "CDI2_EP",
        "CDI2_EP_T",
        "CDI2_FP",
        "CDI2_FP_T",
        "CDI2_IE",
        "CDI2_IE_T",
        "CDI2_IP",
        "CDI2_IP_T",
        "CDI2_NM",
        "CDI2_NM_T",
        "CDI2_NS",
        "CDI2_NS_T",
        "CDI2P_EP",
        "CDI2P_EP_T",
        "CDI2P_FP",
        "CDI2P_FP_T",
        "DTS_absorption",
        "DTS_appraisal",
        "DTS_regulation",
        "DTS_tolerance",
        "Hyperactivity_ClinicalAvg",
        "Inattention_ClinicalAvg",
        "PSI_DC",
        "PSI_DC_T",
        "PSI_PCDI",
        "PSI_PCDI_T",
        "PSI_PD",
        "PSI_PD_T",
        "SCARED_P_GD",
        "SCARED_P_PN",
        "SCARED_P_SC",
        "SCARED_P_SH",
        "SCARED_P_SP",
        "SCARED_SR_GD",
        "SCARED_SR_PN",
        "SCARED_SR_SC",
        "SCARED_SR_SH",
        "SCARED_SR_SP",
        "SDS_DA_Raw",
        "SDS_DA_T",
        "SDS_DIMS_Raw",
        "SDS_DIMS_T",
        "SDS_DOES_Raw",
        "SDS_DOES_T",
        "SDS_SBD_Raw",
        "SDS_SBD_T",
        "SDS_SHY_Raw",
        "SDS_SHY_T",
        "SDS_SWTD_Raw",
        "SDS_SWTD_T",
        "SRS_AWR",
        "SRS_AWR_T",
        "SRS_COG",
        "SRS_COG_T",
        "SRS_COM",
        "SRS_COM_T",
        "SRS_DSMRRB",
        "SRS_DSMRRB_T",
        "SRS_MOT",
        "SRS_MOT_T",
        "SRS_RRB",
        "SRS_RRB_T",
        "SRS_SCI",
        "SRS_SCI_T",
        "STAI_SA",
        "STAI_SA_P",
        "STAI_SA_T",
        "STAI_TA",
        "STAI_TA_P",
        "STAI_TA_T",
        "SWAN_Avg",
        "SWAN_ClinicalAvg",
        "SWAN_HY_Avg",
        "SWAN_IN_Avg",
        "SWAN_P1_ClinicalScore",
        "TRF_Aggressive_Raw",
        "TRF_Aggressive_T",
        "TRF_Anxiety_Raw",
        "TRF_Anxiety_T",
        "TRF_Anxious/Depressed_Raw",
        "TRF_Anxious/Depressed_T",
        "TRF_Attention_Raw",
        "TRF_Attention_T",
        "TRF_Attention/Hyperactivity_Raw",
        "TRF_Attention/Hyperactivity_T",
        "TRF_Conduct_Raw",
        "TRF_Conduct_T",
        "TRF_Depressive_Raw",
        "TRF_Depressive_T",
        "TRF_Externalizing_Raw",
        "TRF_Externalizing_T",
        "TRF_Internalizing_Raw",
        "TRF_Internalizing_T",
        "TRF_Obsessive-Compulsive_T",
        "TRF_Oppositional_Raw",
        "TRF_Oppositional_T",
        "TRF_Other",
        "TRF_Post-traumatic_Raw",
        "TRF_Pre_Aggressive_Raw",
        "TRF_Pre_Aggressive_T",
        "TRF_Pre_Anxiety_Raw",
        "TRF_Pre_Anxiety_T",
        "TRF_Pre_Anxious/Depressed_Raw",
        "TRF_Pre_Anxious/Depressed_T",
        "TRF_Pre_Attention_Raw",
        "TRF_Pre_Attention_T",
        "TRF_Pre_Attention/Hyperactivity_Raw",
        "TRF_Pre_Attention/Hyperactivity_T",
        "TRF_Pre_Autism_Raw",
        "TRF_Pre_Autism_T",
        "TRF_Pre_Depressive_Raw",
        "TRF_Pre_Depressive_T",
        "TRF_Pre_Externalizing_Raw",
        "TRF_Pre_Externalizing_T",
        "TRF_Pre_Internalizing_Raw",
        "TRF_Pre_Internalizing_T",
        "TRF_Pre_Oppositional_Raw",
        "TRF_Pre_Oppositional_T",
        "TRF_Pre_Other",
        "TRF_Pre_Somatic_Raw",
        "TRF_Pre_Somatic_T",
        "TRF_Pre_Thought_Raw",
        "TRF_Pre_Thought_T",
        "TRF_Pre_Withdrawn/Depressed_Raw",
        "TRF_Pre_Withdrawn/Depressed_T",
        "TRF_Rule_Raw",
        "TRF_Rule_T",
        "TRF_Sluggish_Raw",
        "TRF_Social_Raw",
        "TRF_Social_T",
        "TRF_Somatic_Raw",
        "TRF_Somatic_Raw",
        "TRF_Somatic_T",
        "TRF_Somatic_T",
        "TRF_Thought_Raw",
        "TRF_Thought_T",
        "TRF_Withdrawn/Depressed_Raw",
        "TRF_Withdrawn/Depressed_T",
        "YSR_AB",
        "YSR_AB_T",
        "YSR_AD",
        "YSR_AD_T",
        "YSR_AP",
        "YSR_AP_T",
        "YSR_C",
        "YSR_Ext",
        "YSR_Ext_T",
        "YSR_Int",
        "YSR_Int_T",
        "YSR_OP",
        "YSR_RBB",
        "YSR_RBB_T",
        "YSR_SC",
        "YSR_SC_T",
        "YSR_SP",
        "YSR_SP_T",
        "YSR_TP",
        "YSR_TP_T",
        "YSR_WD",
        "YSR_WD_T",
        "APQ_P_INV",
        "APQ_P_PP",
        "APQ_P_PM",
        "APQ_P_ID",
        "APQ_P_CP",
        "APQ_P_OPD"]
for t in unsplit.columns:
    if "Total" in t or "Score" in t or "TOTAL" in t:
        drops.append(t)
keeps = [t for t in unsplit.columns if t not in drops]

# %%
unsplit_no_totals = unsplit[keeps]

# %%
unsplit_no_totals.shape
# Out:
# (221, 902)

# %%
for d in unsplit_no_totals.columns:
    print(d)
# Out:
# EID
# Sex
# Age
# APQ_P_01
# APQ_P_02
# APQ_P_03
# APQ_P_04
# APQ_P_05
# APQ_P_06
# APQ_P_07
# APQ_P_08
# APQ_P_09
# APQ_P_10
# APQ_P_11
# APQ_P_12
# APQ_P_13
# APQ_P_14
# APQ_P_15
# APQ_P_16
# APQ_P_17
# APQ_P_18
# APQ_P_19
# APQ_P_20
# APQ_P_21
# APQ_P_22
# APQ_P_23
# APQ_P_24
# APQ_P_25
# APQ_P_26
# APQ_P_27
# APQ_P_28
# APQ_P_29
# APQ_P_30
# APQ_P_31
# APQ_P_32
# APQ_P_33
# APQ_P_34
# APQ_P_35
# APQ_P_36
# APQ_P_37
# APQ_P_38
# APQ_P_39
# APQ_P_40
# APQ_P_41
# APQ_P_42
# APQ_SR_01
# APQ_SR_01A
# APQ_SR_02
# APQ_SR_03
# APQ_SR_04
# APQ_SR_04A
# APQ_SR_05
# APQ_SR_06
# APQ_SR_07
# APQ_SR_07A
# APQ_SR_08
# APQ_SR_09
# APQ_SR_09A
# APQ_SR_10
# APQ_SR_11
# APQ_SR_11A
# APQ_SR_12
# APQ_SR_13
# APQ_SR_14
# APQ_SR_14A
# APQ_SR_15
# APQ_SR_15A
# APQ_SR_16
# APQ_SR_17
# APQ_SR_18
# APQ_SR_19
# APQ_SR_20
# APQ_SR_20A
# APQ_SR_21
# APQ_SR_22
# APQ_SR_23
# APQ_SR_24
# APQ_SR_25
# APQ_SR_26
# APQ_SR_26A
# APQ_SR_27
# APQ_SR_28
# APQ_SR_29
# APQ_SR_30
# APQ_SR_31
# APQ_SR_32
# APQ_SR_33
# ...

# %%
unsplit_no_totals.to_csv("train_test_data/unsplit_no_totals.csv", index=False)
